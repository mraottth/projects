# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
from scipy import sparse
from sklearn.neighbors import NearestNeighbors
from sklearn.preprocessing import Normalizer
from IPython.display import display
from scipy.sparse.linalg import svds

# %% [markdown]
# ### 0.1 - Load and Prepare Data

# %%
# Load df_books and genres
wd = os.getcwd()
df_books = pd.read_csv(wd + "/data/goodreads_books.csv")
df_inferred_genres = pd.read_csv(wd + "/data/inferred_genres.csv")
genre_descriptors = pd.read_csv(wd + "/data/inferred_genre_top_words.csv")

# Join genres to books
df_books = pd.merge(df_books, df_inferred_genres.drop(columns="title"), how="left", on="book_id")

# %%
# Load sparse_reviews from file
df_reviews = sparse.load_npz(wd + "/data/user_reviews.npz")

# Load user (rows) and book (cols) indices
user_index = pd.read_csv(wd + "/data/user_index_for_sparse_matrix.csv").rename(columns={"0":"user_id"})
book_index = pd.read_csv(wd + "/data/book_index_for_sparse_matrix.csv").rename(columns={"0":"book_id"})

# %%
# Load my goodreads history
my_books = pd.read_csv(wd + "/data/goodreads_library_export.csv")

# Filter to books I've rated
my_books = my_books[["Book Id", "My Rating", "Title"]]\
    .rename(columns={"Book Id":"book_id", "My Rating":"rating", "Title":"title"}).query("rating > 0")
print(f"Target reader ratings: {my_books.shape[0]}")

# Reformat to fit sparse matrix
my_books_1 = pd.merge(
                my_books, df_books[["book_id", "title"]], 
                how="left", on="book_id", suffixes=["_mb","_dfb"]
            )
my_books_id_match = my_books_1[~my_books_1["title_dfb"].isna()]
print(f"Matching on book_id: {my_books_id_match.shape[0]}")

my_books_2 = pd.merge(
    my_books_1[my_books_1["title_dfb"].isna()], df_books[["book_id", "title"]], 
    how="left", left_on="title_mb", right_on="title", suffixes=["_mb","_dfb"]
    )
my_books_match_on_title = my_books_2[~my_books_2["title"].isna()]
print(f"Matching on title: {my_books_match_on_title.shape[0]}")

my_books_id_match = my_books_id_match[["book_id", "rating", "title_dfb"]]\
                        .rename(columns={"title_dfb":"title"})
my_books_match_on_title = my_books_match_on_title[["book_id_dfb", "rating", "title"]]\
                        .rename(columns={"book_id_dfb":"book_id"})

my_books_3 = pd.concat([my_books_id_match, my_books_match_on_title])
my_books_3 = my_books_3.drop_duplicates(subset="book_id")
print(f"Total matches: {my_books_3.shape[0]}, {(my_books_3.shape[0] / my_books.shape[0]):.2%} of total")

my_books_4 = pd.merge(book_index, my_books_3, how="left", on="book_id")#.fillna(0.)
my_books = np.array(my_books_4["rating"]).reshape(1,-1)

# Add to sparse matrix
df_reviews = sparse.vstack([df_reviews, my_books])

# # Normalize reviews within users
# norm = Normalizer()
# df_reviews = norm.fit_transform(df_reviews)
# Out:
# Target reader ratings: 166
# Matching on book_id: 30
# Matching on title: 65
# Total matches: 95, 57.23% of total

# %%
# Set target reader to make recommendations for
target = df_reviews.shape[0] - 1

# %% [markdown]
# #### 0.2 - Functions to Process Recommendations

# %%
# Function to use KNN to find similar users
def find_neighbors(n_neighbors, target_user, ratings_df, ind_books, books):

    # Instantiate KNN
    n_neighbors = n_neighbors

    nn_model = NearestNeighbors(
        metric="cosine",
        algorithm="auto",
        n_neighbors=n_neighbors,
        n_jobs=-1
    )

    # Fit to sparse matrix
    nn_model.fit(ratings_df)

    # Feed in user and get neighbors and distances
    reader = ratings_df[target,:].toarray()
    dists, neighbors = nn_model.kneighbors(reader, return_distance=True)

    similar_users = pd.DataFrame(
        [pd.Series(neighbors.reshape(-1)), pd.Series(dists.reshape(-1))]).T.rename(
            columns={0:"user", 1:"distance"}
    )

    # Get all books read by similar users
    book_ind = []
    book_rat = []
    uid = []
    target_user_books = []
    target_user_book_rat = []
    for nt in similar_users.itertuples():
        user = ratings_df[int(nt.user),:].toarray()
        book_inds = np.where(user[0] > 0)[0]
        ratings = user[0][np.where(user[0] > 0)[0]]
        for i in range(len(book_inds)):        
            book_ind.append(book_inds[i])
            book_rat.append(ratings[i])
            uid.append(nt.user)    
            if nt.distance < 0.000000001:
                target_user_books.append(book_inds[i])
                target_user_book_rat.append(ratings[i])

    neighbor_user_ratings = pd.DataFrame([uid, book_ind, book_rat]).T.rename(
                                columns={0:"uid",1:"book_index",2:"user_rating"}
                            )

    # Join overall rating for each book
    neighbor_user_ratings = pd.merge(
                                ind_books.reset_index(), neighbor_user_ratings, 
                                how="inner", left_on="index", right_on="book_index"
                            )
    neighbor_user_ratings = pd.merge(neighbor_user_ratings, books, how="inner", on="book_id")

    # Filter out books target reader has already read
    neighbor_user_ratings = neighbor_user_ratings[~neighbor_user_ratings["book_index"].isin(target_user_books)]
    neighbor_user_ratings.drop(["index"], axis=1, inplace=True)

    # Filter out later volumes in series using regex pattern
    regex1 = r"#([3-9]|[1-9]\d+)"
    regex2 = r"Vol. ([0-9]|[1-9]\d+)"
    neighbor_user_ratings = neighbor_user_ratings[~neighbor_user_ratings["title"].str.contains(regex1)]
    neighbor_user_ratings = neighbor_user_ratings[~neighbor_user_ratings["title"].str.contains(regex2)]
    neighbor_user_ratings = neighbor_user_ratings[~neighbor_user_ratings["title"].str.contains("#1-")]

    # View target user's ratings
    target_user_ratings = pd.DataFrame(
                            [target_user_books, target_user_book_rat]).T.rename(
                                columns={0:"book_index",1:"user_rating"}
                        )
    target_user_ratings = pd.merge(
                            ind_books.reset_index(), target_user_ratings,
                            how="inner", left_on="index", right_on="book_index"
                        )
    target_user_ratings = pd.merge(target_user_ratings, books, how="inner", on="book_id")    

    return neighbor_user_ratings, target_user_ratings

# %%
# Function to show top recs for each genre
def show_top_recs_by_genre(
        target, others, preds=None, how=["KNN", "MF"], whose_genres=["target", "neighbors"], 
        n_genres=5, min_score=3.9, min_ratings=400, n_recs=15, write_to_excel=False):

    if whose_genres == "target":
        genre_ranking = pd.DataFrame(target.loc[:, "Genre_1":].sum(axis=0).sort_values(ascending=False))
    else:
        genre_ranking = pd.DataFrame(others.loc[:, "Genre_1":].sum(axis=0).sort_values(ascending=False))    
    
    genres = []
    results = []
    # Loop through genres in descending relevance order and print top recs
    for genre in genre_ranking.index[0:n_genres]:        
        
        g = float(genre[6:])
        if how == "KNN":
            highest_rated_recs_genre = others.query("main_genre == @g")\
                .groupby(["title", "avg_rating", "ratings_count", "year", "url"])["book_id"]\
                .count().reset_index().sort_values(by=["avg_rating", "book_id"], ascending=False)
        
        elif how == "MF":
            highest_rated_recs_genre = preds.query("main_genre == @g")\
            .sort_values(by="predicted_rating", ascending=False)                

        highest_rated_recs_genre = highest_rated_recs_genre.query(
                                        "ratings_count > @min_ratings & avg_rating > @min_score"
                                    )

        # Print genre name and descriptor
        for nt in genre_descriptors.itertuples():
            genre_rep = genre.replace("_"," ")
            if nt.genre_string[0:len(f"{genre}:")] == f"{genre_rep}:":
                gs = (nt.genre_string)
        
        genres.append(gs)
        results.append(highest_rated_recs_genre[["title", "avg_rating", "ratings_count", "url"]].head(50))

        print(gs)
        display(highest_rated_recs_genre[["title", "avg_rating", "ratings_count", "url"]].head(n_recs))
        print("_____\n")
    
    # Write to excel if keyword set
    path = (wd + "/data/book_recs.xlsx")
    if write_to_excel == True:
        if os.path.isfile(path):
            with pd.ExcelWriter(path, engine="openpyxl", mode="a", if_sheet_exists='replace') as writer:
                
                pd.DataFrame(genres).rename(columns={0:"Genres"})\
                    .to_excel(writer, sheet_name="Genre Meanings", index=False)
                
                for i in range(len(results)):
                    results[i].to_excel(writer, sheet_name=f"{genres[i].split(':')[0]} Recs", index=False)
        else:
            with pd.ExcelWriter(path) as writer:
                
                pd.DataFrame(genres).rename(columns={0:"Genres"})\
                    .to_excel(writer, sheet_name="Genre Meanings", index=False)
                
                for i in range(len(results)):
                    results[i].to_excel(writer, sheet_name=f"{genres[i].split(':')[0]} Recs", index=False)
        writer.close

# %%
# Functions to show top rated and most popular among similar readers
def neighbors_most_popular(others, n=10, min_ratings=1000, min_score=3.8):
    
    popular_recs = others.query("ratings_count > @min_ratings & avg_rating > @min_score")\
        .groupby(["title", "avg_rating", "ratings_count", "year","url"])["book_id"]\
        .count().reset_index().sort_values(by=["book_id", "avg_rating"], ascending=False)\
        .nlargest(n, "book_id").rename(columns={"book_id":"percent_similar_users_read"})

    popular_recs["percent_similar_users_read"] = (popular_recs["percent_similar_users_read"] / 
                                                    others["uid"].nunique()).map('{:.1%}'.format)
    return popular_recs[["title","avg_rating","ratings_count","year","percent_similar_users_read","url"]]


def neighbors_top_rated(others, n=10, min_ratings=1000, min_score=3.8):

    highest_rated_recs = others.query("ratings_count > @min_ratings & avg_rating > @min_score")\
        .groupby(["title", "avg_rating", "ratings_count", "year","url"])["book_id"]\
        .count().reset_index().sort_values(by=["avg_rating", "book_id"], ascending=False)\
        .nlargest(n, "avg_rating").drop(columns="book_id")

    return highest_rated_recs

# %%
# Function to plot neighbors' and target's top genres
def plot_top_genres(others, target):
    
    fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(12,10))
    neighbor_genre_ranking = pd.DataFrame(others.loc[:, "Genre_1":].sum(axis=0).sort_values(ascending=False))
    target_genre_ranking = pd.DataFrame(target.loc[:, "Genre_1":].sum(axis=0).sort_values(ascending=False))
    
    sns.barplot(
        data=neighbor_genre_ranking, y=neighbor_genre_ranking.index, x=0, ax=ax[0]
    )
    ax[0].set_xlabel("Genre preference")
    ax[0].set_title("Neighbors' Top Genres")

    # Plot target reader's top genres    
    sns.barplot(
        data=target_genre_ranking, y=target_genre_ranking.index, x=0, ax=ax[1]
    )
    ax[1].set_xlabel("Genre preference")
    ax[1].set_title("Target User's Top Genres")
    
    plt.show()

# %% [markdown]
# ## TESTING using gradient descent for matrix factorization

# %%
# Find larger number of similar users than before to get broad pool of potentially relevant books
df_reviews.data[np.isnan(df_reviews.data)] = 0
df_reviews = sparse.csr_matrix(df_reviews)
large_neighborhood_ratings, target_user_ratings = find_neighbors(1000, target, df_reviews, book_index, df_books)

# Get unique users and books to slice df_reviews
neighbor_index = large_neighborhood_ratings["uid"].unique()
neighbor_index = np.append(neighbor_index, target)
neighbor_book_index = large_neighborhood_ratings["book_index"].unique()
neighbor_book_index = np.append(neighbor_book_index, target_user_ratings["book_index"].unique())

# Slice df_reviews to make User Ratings Matrix
df_reviews.data[df_reviews.data == 0] = np.nan
df_reviews = sparse.csr_matrix(df_reviews)
R = df_reviews[:, neighbor_book_index]
R = R[neighbor_index, :].toarray()
# Out:
# /var/folders/hf/1k3w_wb93bd1yp7b5_jh65mw0000gn/T/ipykernel_14241/903381106.py:62: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   neighbor_user_ratings = neighbor_user_ratings[~neighbor_user_ratings["title"].str.contains(regex1)]
# /var/folders/hf/1k3w_wb93bd1yp7b5_jh65mw0000gn/T/ipykernel_14241/903381106.py:63: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   neighbor_user_ratings = neighbor_user_ratings[~neighbor_user_ratings["title"].str.contains(regex2)]

# %%
# def matrix_factorization1(R, k=5, steps=4000, lr=0.0002, beta=0.02, verbose=0):
#     """
#     Uses gradient descent to train matrix factorization algorithm. Useful explanation
#     of the math here: 
#     http://www.quuxlabs.com/blog/2010/09/matrix-factorization-a-simple-tutorial-and-implementation-in-python/#source-code

#     Args:
#         R: Utility matrix of user item ratings         
#         k: Number of latent features
#         steps: Number of epochs to run training
#         lr: Learning rate
#         beta: Regularization strength
#         verbose: Prints updates if 1

#     Returns:
#         Predictions, User Embeddings, Item Embdeddings
#     """
#     # Initialize random values for user (P) and book (Q) embedding matrices
#     P = np.random.rand(R.shape[0],K)
#     Q = np.random.rand(R.shape[1],K).T
    
#     for step in range(steps): # For each steps
#         r_0 = np.where(R > 0) # Find indices where rating > 0
#         e = 0 # Initialize error for step to 0
#         for n in range(len(r_0[0])): # For each value where rating > 0
#             i = r_0[0][n] # Get the row index where the value is
#             j = r_0[1][n] # Get the column index where the value is
#             resid = R[i][j] - np.dot(P[i,:],Q[:,j]) # residual is value - r_hat
#             e = e + pow(R[i][j] - np.dot(P[i,:],Q[:,j]), 2) # Add to error
#             for k in range(K): # for each component (latent feature)       
#                 P[i][k] = P[i][k] + lr * (2 * resid * Q[k][j] - beta * P[i][k]) # Update P by step in gradient
#                 Q[k][j] = Q[k][j] + lr * (2 * resid * P[i][k] - beta * Q[k][j]) # Update Q by step in gradient
#                 e = e + (beta/2) * (pow(P[i][k],2) + pow(Q[k][j],2)) # Update error with regularized term

#         # View progress
#         if verbose == 1:
#             if step % (steps / 10) == 0:
#                 print(f"Step: {step}, error: {e}")
        
#         # Break loop if error is very small
#         if e < 0.001:
#             break
    
#     # Get predictions
#     preds = np.dot(P, Q)

#     return preds, P, Q.T

# %%
# Function to train embedding matrices using alternating least squares (ALS) and make predictions 
def matrix_factorization(R, k=5, steps=4000, lr=0.0002, beta=0.02, verbose=0):
    """
    Uses gradient descent to train matrix factorization algorithm. Useful explanation
    of the math here: 
    http://www.quuxlabs.com/blog/2010/09/matrix-factorization-a-simple-tutorial-and-implementation-in-python/#source-code

    Args:
        R: Utility matrix of user item ratings         
        k: Number of latent features
        steps: Number of epochs to run training
        lr: Learning rate
        beta: Regularization strength
        verbose: Prints updates if 1

    Returns:
        Predictions, User Embeddings, Item Embdeddings
    """

    # Initialize random values for user (P) and book (Q) embedding matrices
    K = k
    P = np.random.rand(R.shape[0],k)
    Q = np.random.rand(R.shape[1],k).T

    for step in range(steps): # For each steps
        r_0 = np.where(R > 0) # Find indices where rating > 0
        e = 0 # Initialize error for step to 0
        i = r_0[0]
        j = r_0[1]
        resid = R[i,j] - (P @ Q)[i,j] # residual is value - r_hat       
        for k in range(K): # for each component (latent feature)                
            P[i,k] = P[i,k] + lr * (2 * resid * Q[k,j] - beta * P[i,k]) # Update P by step in gradient                             
            Q[k,j] = Q[k,j] + lr * (2 * resid * P[i,k] - beta * Q[k,j]) # Update Q by step in gradient            

        # Calculate error every 1k steps
        e = 0 # Initialize counter for error            
        if (step + 1) % 1000 == 0: # Only do every 1k steps
            e = e + np.sum(pow(resid, 2)) # Add to error
            for k in range(K): # for each component (latent feature)                             
                e = e + (beta/2) * np.sum(pow(P[i,k],2) + pow(Q[k,j],2)) # Update error with regularized term

            # View progress
            if verbose == 1:
                print(f"Step: {step + 1}, error: {e}") # Print update                           

        # # Break loop if error is very small
        # if (step > 1500) & (e < 0.001):
        #     break
    
    # Get predictions
    preds = np.dot(P, Q)

    return preds, P, Q.T

# %%
preds, user_embeddings, item_embeddings = matrix_factorization(R, k=30, steps=3000, verbose=1)

# %%
# Make dataframe from predictions and indices
df_preds = pd.DataFrame(preds, columns=neighbor_book_index, index=neighbor_index)\
                .reset_index()

# Get target user's top predicted ratings
target_pred_books = df_preds[df_preds["index"] == target].columns[1:]
target_pred_ratings = df_preds[df_preds["index"] == target].values[0][1:]

# Put into df with relevant info from df_books
top_preds = pd.DataFrame({"book_index":target_pred_books, "predicted_rating":target_pred_ratings})\
                .sort_values(by="predicted_rating", ascending=False)\
                .merge(book_index.reset_index(), left_on="book_index", right_on="index")\
                .merge(
                    df_books[["book_id", "title", "avg_rating", "ratings_count", "year", "main_genre","url"]],
                    on="book_id"
                )\
                .drop(columns=["index"])

# View preds on actually read books
target_books_preds = top_preds[top_preds["book_index"].isin(target_user_ratings["book_index"].unique())]\
                        .drop(["book_index"], axis=1)
target_books_preds = pd.merge(target_books_preds, target_user_ratings[["book_id", "user_rating"]], on="book_id")
target_books_preds["diff"] = target_books_preds["predicted_rating"] - target_books_preds["user_rating"]
print("Predictions on Actually Read Books")
display(target_books_preds[["title", "predicted_rating", "user_rating", "diff"]])

# Filter out already read books to get top preds
print("___________\n")
print("Predictions on Unread Books")
top_preds = top_preds[~top_preds["book_index"].isin(target_user_ratings["book_index"].unique())]
display(top_preds[["title","avg_rating","predicted_rating","ratings_count","year","url"]]\
        .query("avg_rating > 3.9").head(20)
    )
# Out:
# Predictions on Actually Read Books
#                                                 title  predicted_rating  \
# 0   The Dark Forest (Remembrance of Earth’s Past, #2)          4.708837
# 1                                                1984          4.707979
# 2                  The Ones Who Walk Away from Omelas          4.699686
# 3                                          Steve Jobs          4.687123
# 4   The Three-Body Problem (Remembrance of Earth’s...          4.683958
# ..                                                ...               ...
# 90                     Seven Brief Lessons on Physics          1.890757
# 91  The One Thing: The Surprisingly Simple Truth B...          1.889901
# 92  Steal Like an Artist: 10 Things Nobody Told Yo...          1.856815
# 93  Hillbilly Elegy: A Memoir of a Family and Cult...          1.058190
# 94                     Casino Royale (James Bond, #1)          1.001830
#
#     user_rating      diff
# 0           5.0 -0.291163
# 1           5.0 -0.292021
# 2           5.0 -0.300314
# 3           5.0 -0.312877
# 4           5.0 -0.316042
# ..          ...       ...
# 90          2.0 -0.109243
# 91          2.0 -0.110099
# 92          2.0 -0.143185
# 93          1.0  0.058190
# 94          1.0  0.001830
#
# [95 rows x 4 columns]
# ___________
#
# Predictions on Unread Books
#                                                 title  avg_rating  \
# 0                                The Farming of Bones        4.06
# 1   When Food Is Love: Exploring the Relationship ...        4.00
# 16  The Outer Limits of Reason: What Science, Math...        3.99
# 21  The Power of Vulnerability: Teachings of Authe...        4.57
# 29                              The Secret of Secrets        4.43
# 30  Scheisshaus Luck: Surviving the Unspeakable in...        4.09
# 31  Every Body Yoga: Let Go of Fear. Get On the Ma...        4.34
# 32                       A General Theory of Oblivion        3.91
# 33              This is the Story of a Happy Marriage        4.03
# 40             My Kind of Wonderful (Cedar Ridge, #2)        4.09
# 41                                 The Husband Stitch        4.37
# 42          It Started With a Kiss (Sequoia Lake, #1)        4.19
# 43          Who We Are (Bear, Otter, and the Kid, #2)        4.47
# 46      Natasha's Dance: A Cultural History of Russia        4.16
# 47     The Kid Stays In The Picture: A Hollywood Life        3.93
# 48                                     The Wish Child        4.19
# 49                           The Roots of Romanticism        4.24
# 51   Indonesia, Etc.: Exploring the Improbable Nation        4.18
# 53                                       Batman: Hush        4.29
# 54                                     Tourist Season        3.95
#
#     predicted_rating  ratings_count  year  \
# 0           5.171440         5843.0  1999
# 1           4.867436         1303.0  1991
# 16          4.638082          342.0  2013
# 21          4.623207         3778.0  2013
# 29          4.570730          323.0  1997
# 30          4.541463         1049.0  2008
# 31          4.520398          619.0  2017
# 32          4.513305          862.0  2015
# 33          4.486513        13538.0  2013
# 40          4.394610         3181.0  2015
# 41          4.388181          305.0  2014
# 42          4.366174          927.0  2017
# 43          4.350853         4184.0  2012
# 46          4.314807         2039.0  2002
# 47          4.301864          279.0  2013
# 48          4.287924          173.0  2017
# 49          4.273103          437.0  2001
# 51          4.255733          470.0  2014
# 53          4.223500        25146.0  2009
# 54          4.211958        14026.0  1986
#
#                                                   url
# 0   https://www.goodreads.com/book/show/31115.The_...
# 1   https://www.goodreads.com/book/show/39175.When...
# 16  https://www.goodreads.com/book/show/17841838-t...
# 21  https://www.goodreads.com/book/show/23500254-t...
# 29  https://www.goodreads.com/book/show/530479.The...
# 30  https://www.goodreads.com/book/show/3930572-sc...
# 31  https://www.goodreads.com/book/show/30754069-e...
# 32  https://www.goodreads.com/book/show/23346410-a...
# 33  https://www.goodreads.com/book/show/17349222-t...
# 40  https://www.goodreads.com/book/show/25317360-m...
# 41  https://www.goodreads.com/book/show/25056903-t...
# 42  https://www.goodreads.com/book/show/30046605-i...
# 43  https://www.goodreads.com/book/show/13579947-w...
# 46  https://www.goodreads.com/book/show/97401.Nata...
# 47  https://www.goodreads.com/book/show/18755857-t...
# 48  https://www.goodreads.com/book/show/30965710-t...
# 49  https://www.goodreads.com/book/show/84713.The_...
# 51  https://www.goodreads.com/book/show/18377963-i...
# 53  https://www.goodreads.com/book/show/6375845-ba...
# 54  https://www.goodreads.com/book/show/13064.Tour...

# %%
# Highest rated books by each of the top genres
show_top_recs_by_genre(
    target_user_ratings, 
    large_neighborhood_ratings, 
    preds=top_preds, 
    how="MF", 
    whose_genres="target", 
    n_genres=10, 
    min_score=4.15, 
    min_ratings=400, 
    n_recs=20,
    write_to_excel=True
)
# Out:
# Genre 5: ['history', 'war', 'political', 'account', 'world', 'year', 'country', 'family', 'century', 'people']
#                                                  title  avg_rating  \
# 51    Indonesia, Etc.: Exploring the Improbable Nation        4.18
# 64   Destiny Disrupted: A History of the World Thro...        4.34
# 129                      Conversation in the Cathedral        4.32
# 223  My Promised Land: The Triumph and Tragedy of I...        4.22
# 260  The Girl with Seven Names: A North Korean Defe...        4.45
# 272                        March: Book One (March, #1)        4.34
# 279  Arch of Triumph: A Novel of a Man Without a Co...        4.40
# 322          Shoe Dog: A Memoir by the Creator of NIKE        4.44
# 357  The New Jim Crow: Mass Incarceration in the Ag...        4.49
# 379         The Silk Roads: A New History of the World        4.25
# 408  The Dark Side: The Inside Story of How the War...        4.18
# 411                                            Jubilee        4.23
# 413  Dear Leader: Poet, Spy, Escapee—A Look Inside ...        4.29
# 415                                          Diplomacy        4.18
# 421  Black Earth: The Holocaust as History and Warning        4.21
# 436                        March: Book Two (March, #2)        4.54
# 443                                             Kaputt        4.16
# 454         From #blacklivesmatter To Black Liberation        4.54
# 475                                Escape from Freedom        4.23
# 483  Crazy Is My Superpower:  How I Triumphed by Br...        4.48
#
#      ratings_count                                                url
# 51           470.0  https://www.goodreads.com/book/show/18377963-i...
# 64           416.0  https://www.goodreads.com/book/show/6715481-de...
# 129         3331.0  https://www.goodreads.com/book/show/53970.Conv...
# 223         4226.0  https://www.goodreads.com/book/show/15798334-m...
# 260         8293.0  https://www.goodreads.com/book/show/25362017-t...
# 272        21092.0  https://www.goodreads.com/book/show/17346698-m...
# 279        11703.0  https://www.goodreads.com/book/show/672948.Arc...
# 322        27468.0  https://www.goodreads.com/book/show/27220736-s...
# 357        24694.0  https://www.goodreads.com/book/show/6792458-th...
# 379         3022.0  https://www.goodreads.com/book/show/25812847-t...
# 408         3163.0  https://www.goodreads.com/book/show/3280003-th...
# 411         2961.0  https://www.goodreads.com/book/show/571420.Jub...
# 413         2732.0  https://www.goodreads.com/book/show/20736640-d...
# 415         4584.0  https://www.goodreads.com/book/show/781183.Dip...
# 421         1133.0  https://www.goodreads.com/book/show/23995415-b...
# 436        10428.0  https://www.goodreads.com/book/show/22487952-m...
# 443          845.0  https://www.goodreads.com/book/show/138428.Kaputt
# 454          548.0  https://www.goodreads.com/book/show/25330220-f...
# 475         5910.0  https://www.goodreads.com/book/show/25491.Esca...
# 483          551.0  https://www.goodreads.com/book/show/27866300-c...
# _____
#
# Genre 15: ['history', 'poem', 'essay', 'text', 'century', 'collection', 'world', 'writing', 'introduction', 'literature']
#                                                  title  avg_rating  \
# 46       Natasha's Dance: A Cultural History of Russia        4.16
# 49                            The Roots of Romanticism        4.24
# 56                           Complete Poems, 1904-1962        4.35
# 59                Teaching My Mother How to Give Birth        4.38
# 67   Tranny: Confessions of Punk Rock's Most Infamo...        4.23
# 76            The Camera (Ansel Adams Photography, #1)        4.22
# 125        A Call to Conscience: The Landmark Speeches        4.53
# 182                                         In a Grove        4.19
# 187                         We Should All Be Feminists        4.47
# 197  The World of Ice & Fire: The Untold History of...        4.26
# 226  Surely You're Joking, Mr. Feynman!: Adventures...        4.29
# 243                                    Collected Poems        4.26
# 247                             The Book of Nightmares        4.24
# 253      String Theory: David Foster Wallace on Tennis        4.24
# 288  Notes from Underground, White Nights, The Drea...        4.17
# 308  The Fire This Time: A New Generation Speaks ab...        4.35
# 427          Pioneer Girl: The Annotated Autobiography        4.19
# 470                                The Science of Mind        4.38
# 503  At the Existentialist Café: Freedom, Being, an...        4.22
# 549  Short Stories from Hogwarts of Heroism, Hardsh...        4.23
#
#      ratings_count                                                url
# 46          2039.0  https://www.goodreads.com/book/show/97401.Nata...
# 49           437.0  https://www.goodreads.com/book/show/84713.The_...
# 56         18787.0  https://www.goodreads.com/book/show/26596.Comp...
# 59          7830.0  https://www.goodreads.com/book/show/13376363-t...
# 67          2655.0  https://www.goodreads.com/book/show/29467305-t...
# 76          2663.0  https://www.goodreads.com/book/show/20501.The_...
# 125          502.0  https://www.goodreads.com/book/show/225073.A_C...
# 182         1012.0  https://www.goodreads.com/book/show/8132998-in...
# 187         1351.0  https://www.goodreads.com/book/show/23301818-w...
# 197        12952.0  https://www.goodreads.com/book/show/17345242-t...
# 226        95353.0  https://www.goodreads.com/book/show/5544.Surel...
# 243         5180.0  https://www.goodreads.com/book/show/321538.Col...
# 247         1978.0  https://www.goodreads.com/book/show/18901.The_...
# 253          949.0  https://www.goodreads.com/book/show/27246166-s...
# 288        66680.0  https://www.goodreads.com/book/show/17876.Note...
# 308         2309.0  https://www.goodreads.com/book/show/28505023-t...
# 427         4617.0  https://www.goodreads.com/book/show/22212838-p...
# 470         1398.0  https://www.goodreads.com/book/show/149197.The...
# 503         2298.0  https://www.goodreads.com/book/show/25658482-a...
# 549        16961.0  https://www.goodreads.com/book/show/31538635-s...
# _____
#
# Genre 17: ['alien', 'planet', 'world', 'human', 'ship', 'space', 'war', 'crew', 'mission', 'race']
#                                                   title  avg_rating  \
# 148                             The Abyss Beyond Dreams        4.21
# 206                               The Evolutionary Void        4.26
# 286                     Wolf by Wolf (Wolf by Wolf, #1)        4.28
# 586                    Kings of the Wyld (The Band, #1)        4.42
# 621   The Winter Fortress: The Epic Mission to Sabot...        4.23
# 688   The World Is Blue: How Our Fate and the Ocean'...        4.19
# 706   Foundation / Foundation and Empire / Second Fo...        4.35
# 733       The Honor of the Queen (Honor Harrington, #2)        4.21
# 822                     Caliban's War (The Expanse, #2)        4.29
# 855                Spellbound (Grimnoir Chronicles, #2)        4.29
# 949                        Machine Moon (Descender, #2)        4.20
# 979                                          Lost Stars        4.25
# 1023  Avatar: The Last Airbender: The Promise, Part ...        4.24
# 1467  Deep: Freediving, Renegade Science, and What t...        4.40
# 1532                       Leviathan Wakes (Expanse #1)        4.20
# 1555                  Adulthood Rites (Xenogenesis, #2)        4.16
# 1828  The Last Rhinos: My Battle to Save One of the ...        4.34
# 1946                              I, Robot (Robot #0.1)        4.17
# 2281  The Hyperion Omnibus: Hyperion / The Fall of H...        4.41
# 2318  The Deep: The Extraordinary Creatures of the A...        4.28
#
#       ratings_count                                                url
# 148          4944.0  https://www.goodreads.com/book/show/20697413-t...
# 206         13729.0  https://www.goodreads.com/book/show/7438179-th...
# 286          9710.0  https://www.goodreads.com/book/show/24807186-w...
# 586          2285.0  https://www.goodreads.com/book/show/30841984-k...
# 621          1057.0  https://www.goodreads.com/book/show/25897720-t...
# 688           486.0  https://www.goodreads.com/book/show/6885052-th...
# 706          3316.0  https://www.goodreads.com/book/show/278097.Fou...
# 733           487.0  https://www.goodreads.com/book/show/261758.The...
# 822         41459.0  https://www.goodreads.com/book/show/12591698-c...
# 855          7184.0  https://www.goodreads.com/book/show/10822283-s...
# 949          3275.0  https://www.goodreads.com/book/show/28204537-d...
# 979          9512.0  https://www.goodreads.com/book/show/25067046-l...
# 1023        18987.0  https://www.goodreads.com/book/show/12413836-a...
# 1467         1144.0  https://www.goodreads.com/book/show/18222705-deep
# 1532         1998.0  https://www.goodreads.com/book/show/9533361-le...
# 1555         7081.0  https://www.goodreads.com/book/show/116249.Adu...
# 1828         1094.0  https://www.goodreads.com/book/show/13167157-t...
# 1946       201196.0  https://www.goodreads.com/book/show/41804.I_Robot
# 2281         2254.0  https://www.goodreads.com/book/show/3943.The_H...
# 2318          901.0  https://www.goodreads.com/book/show/442668.The...
# _____
#
# Genre 8: ['guide', 'people', 'way', 'help', 'practical', 'world', 'experience', 'offer', 'question', 'business']
#                                                  title  avg_rating  \
# 21   The Power of Vulnerability: Teachings of Authe...        4.57
# 31   Every Body Yoga: Let Go of Fear. Get On the Ma...        4.34
# 84                                          Loving God        4.31
# 107  Mountains Beyond Mountains: The Quest of Dr. P...        4.21
# 114  The Story of the Human Body: Evolution, Health...        4.21
# 220  The Hard Thing About Hard Things: Building a B...        4.20
# 235                       The Power of a Praying Woman        4.38
# 284  The Pleasures of God: Meditations on God's Del...        4.33
# 291  The (7L) The Seven Levels of Communication: Go...        4.33
# 301  Ready to Run: Unlocking Your Potential to Run ...        4.29
# 329  Come as You Are: The Surprising New Science th...        4.23
# 335  Vegan's Daily Companion: 365 Days of Inspirati...        4.22
# 385  Radical Acceptance: Embracing Your Life With t...        4.25
# 462  Autism's False Prophets: Bad Science, Risky Me...        4.18
# 541                                          Unashamed        4.45
# 582  There Is No Good Card for This: What To Say an...        4.31
# 637  A Praying Life: Connecting with God in a Distr...        4.30
# 718         Dont Make Me Think And Html World Wide Web        4.24
# 815          Totto-chan: The Little Girl at the Window        4.30
# 818  A Mind for Numbers: How to Excel at Math and S...        4.22
#
#      ratings_count                                                url
# 21          3778.0  https://www.goodreads.com/book/show/23500254-t...
# 31           619.0  https://www.goodreads.com/book/show/30754069-e...
# 84          1342.0  https://www.goodreads.com/book/show/903912.Lov...
# 107        53936.0  https://www.goodreads.com/book/show/10235.Moun...
# 114         2759.0  https://www.goodreads.com/book/show/17736859-t...
# 220        20745.0  https://www.goodreads.com/book/show/18176747-t...
# 235         9867.0  https://www.goodreads.com/book/show/18054709-t...
# 284         4596.0  https://www.goodreads.com/book/show/45364.The_...
# 291          482.0  https://www.goodreads.com/book/show/9858250-th...
# 301          772.0  https://www.goodreads.com/book/show/18668429-r...
# 329         3258.0  https://www.goodreads.com/book/show/22609341-c...
# 335          739.0  https://www.goodreads.com/book/show/9462708-ve...
# 385         8593.0  https://www.goodreads.com/book/show/173666.Rad...
# 462          987.0  https://www.goodreads.com/book/show/3360358-au...
# 541         1747.0  https://www.goodreads.com/book/show/25802615-u...
# 582          547.0  https://www.goodreads.com/book/show/28257714-t...
# 637         7482.0  https://www.goodreads.com/book/show/6426403-a-...
# 718          653.0  https://www.goodreads.com/book/show/1210562.Do...
# 815        14456.0  https://www.goodreads.com/book/show/328802.Tot...
# 818         4158.0  https://www.goodreads.com/book/show/18693655-a...
# _____
#
# Genre 11: ['fiction', 'collection', 'world', 'literary', 'young', 'funny', 'short', 'comedy', 'horror', 'debut']
#                                                   title  avg_rating  \
# 508                                          Incidences        4.32
# 672                                      Asterios Polyp        4.19
# 683                                     Peter and Alice        4.44
# 735     Absolute Pandemonium: My Louder Than Life Story        4.20
# 1127               The Essential Dykes to Watch Out For        4.36
# 1224                                              Tales        4.37
# 1761  A Supposedly Fun Thing I'll Never Do Again:  E...        4.28
# 2232                                 The Faraway Nearby        4.19
# 2634                            Ministry of Moral Panic        4.24
# 2766      A Manual for Cleaning Women: Selected Stories        4.17
# 2822  Sherlock Holmes: The Complete Novels and Stori...        4.45
# 2835                    The Exploits of Sherlock Holmes        4.41
# 3183  Love's Executioner and Other Tales of Psychoth...        4.18
# 3468                    The Last Wish (The Witcher, #1)        4.20
# 4033                        The Refrigerator Monologues        4.21
# 4067  Beautiful Outlaw: Experiencing the Playful, Di...        4.31
#
#       ratings_count                                                url
# 508           658.0  https://www.goodreads.com/book/show/685172.Inc...
# 672         20053.0  https://www.goodreads.com/book/show/4070095-as...
# 683           561.0  https://www.goodreads.com/book/show/17347724-p...
# 735           604.0  https://www.goodreads.com/book/show/26036990-a...
# 1127         6979.0  https://www.goodreads.com/book/show/3189884-th...
# 1224         2100.0    https://www.goodreads.com/book/show/36313.Tales
# 1761        23746.0  https://www.goodreads.com/book/show/6748.A_Sup...
# 2232         3409.0  https://www.goodreads.com/book/show/16158561-t...
# 2634          557.0  https://www.goodreads.com/book/show/17238889-m...
# 2766         6863.0  https://www.goodreads.com/book/show/22929586-a...
# 2822        18729.0  https://www.goodreads.com/book/show/3581.Sherl...
# 2835        26933.0  https://www.goodreads.com/book/show/76104.The_...
# 3183        14376.0  https://www.goodreads.com/book/show/21027.Love...
# 3468         1610.0  https://www.goodreads.com/book/show/11570030-t...
# 4033          894.0  https://www.goodreads.com/book/show/32714267-t...
# 4067         2633.0  https://www.goodreads.com/book/show/12079560-b...
# _____
#
# Genre 22: ['world', 'power', 'enemy', 'war', 'battle', 'evil', 'magic', 'save', 'ancient', 'warrior']
#                                                   title  avg_rating  \
# 66                          Blackwing (Ravens' Mark #1)        4.24
# 122                           Everwild (Skinjacker, #2)        4.21
# 124                        Legend (The Drenai Saga, #1)        4.25
# 146                      Asterix the Gaul (Asterix, #1)        4.16
# 155                          Mara, Daughter of the Nile        4.23
# 190   Avatar: The Last Airbender: The Search, Part 2...        4.35
# 229    The Assassin's Blade (Throne of Glass, #0.1-0.5)        4.48
# 355                               Villains by Necessity        4.19
# 448                        Scythe (Arc of a Scythe, #1)        4.30
# 546                   Dawn of Wonder (The Wakening, #1)        4.35
# 577      The Wall of Storms (The Dandelion Dynasty, #2)        4.33
# 607        The False Prince (The Ascendance Trilogy #1)        4.23
# 781   The Shadow of What Was Lost (The Licanius Tril...        4.16
# 841   When Christ and His Saints Slept  (Henry II an...        4.27
# 867   The Hammer of Thor (Magnus Chase and the Gods ...        4.37
# 890                  Blood for Blood (Wolf By Wolf, #2)        4.33
# 942         Free the Darkness (King's Dark Tidings, #1)        4.30
# 978                                          The Cartel        4.29
# 1090  The Sword of Summer (Magnus Chase and The Gods...        4.26
# 1105  Avatar: The Last Airbender: The Promise, Part ...        4.43
#
#       ratings_count                                                url
# 66            401.0  https://www.goodreads.com/book/show/33916060-b...
# 122          9779.0  https://www.goodreads.com/book/show/6390465-ev...
# 124         18805.0  https://www.goodreads.com/book/show/618177.Legend
# 146         17151.0  https://www.goodreads.com/book/show/71292.Aste...
# 155          7903.0  https://www.goodreads.com/book/show/406186.Mar...
# 190          4658.0  https://www.goodreads.com/book/show/17445144-a...
# 229          2010.0  https://www.goodreads.com/book/show/18594430-t...
# 355          1116.0  https://www.goodreads.com/book/show/401454.Vil...
# 448         13000.0  https://www.goodreads.com/book/show/28954189-s...
# 546         13351.0  https://www.goodreads.com/book/show/25451852-d...
# 577          1078.0  https://www.goodreads.com/book/show/18952381-t...
# 607         51292.0  https://www.goodreads.com/book/show/12432220-t...
# 781          6120.0  https://www.goodreads.com/book/show/22878967-t...
# 841         10892.0  https://www.goodreads.com/book/show/43841.When...
# 867         26454.0  https://www.goodreads.com/book/show/27904311-t...
# 890          3402.0  https://www.goodreads.com/book/show/26864835-b...
# 942          6591.0  https://www.goodreads.com/book/show/28385685-f...
# 978          9961.0  https://www.goodreads.com/book/show/23602561-t...
# 1090          921.0  https://www.goodreads.com/book/show/25909686-t...
# 1105        12655.0  https://www.goodreads.com/book/show/13096848-a...
# _____
#
# Genre 3: ['collection', 'comic', 'short', 'fan', 'feature', 'bestselling', 'adventure', 'available', 'classic', 'includes']
#                                                   title  avg_rating  \
# 135        A Good Man is Hard to Find and Other Stories        4.24
# 166       Y: The Last Man - The Deluxe Edition Book One        4.36
# 394                                     The Private Eye        4.24
# 401                                               Groot        4.35
# 404                                    The Clown of God        4.21
# 469                                    Preacher, Book 4        4.27
# 531                           The Guild (The Guild, #1)        4.22
# 553   A History of the English Speaking Peoples, 4 Vols        4.31
# 652   The Glory of Their Times: The Story of the Ear...        4.32
# 866                                  The Julian Chapter        4.32
# 873   Walt Disney Imagineering: A Behind the Dreams ...        4.23
# 905                                   Calvin and Hobbes        4.61
# 925                                 The Paper Menagerie        4.37
# 948   The Lord of the Rings: The Two Towers: Visual ...        4.51
# 1001  The Complete Clive Barker's The Great And Secr...        4.21
# 1092                             Make Way for Ducklings        4.22
# 1279     Harry Potter: The Prequel (Harry Potter, #0.5)        4.22
# 1562                                     Saga: Book One        4.70
# 1821                Adventure Time With Fionna and Cake        4.41
# 2076                    The Mysteries of Harris Burdick        4.53
#
#       ratings_count                                                url
# 135         26384.0  https://www.goodreads.com/book/show/48464.A_Go...
# 166         10549.0      https://www.goodreads.com/book/show/3710603-y
# 394          1847.0  https://www.goodreads.com/book/show/26247784-t...
# 401           979.0  https://www.goodreads.com/book/show/26030887-g...
# 404          2353.0  https://www.goodreads.com/book/show/69086.The_...
# 469          1535.0  https://www.goodreads.com/book/show/9785203-pr...
# 531          4861.0  https://www.goodreads.com/book/show/8693600-th...
# 553           767.0  https://www.goodreads.com/book/show/1644043.A_...
# 652          3025.0  https://www.goodreads.com/book/show/461749.The...
# 866         11380.0  https://www.goodreads.com/book/show/20878809-t...
# 873          1279.0  https://www.goodreads.com/book/show/380248.Wal...
# 905        120371.0  https://www.goodreads.com/book/show/77727.Calv...
# 925          2476.0  https://www.goodreads.com/book/show/13501210-t...
# 948          4463.0  https://www.goodreads.com/book/show/15221.The_...
# 1001        15868.0  https://www.goodreads.com/book/show/34871.The_...
# 1092        71133.0  https://www.goodreads.com/book/show/29291.Make...
# 1279        13267.0  https://www.goodreads.com/book/show/8933944-ha...
# 1562         4201.0  https://www.goodreads.com/book/show/22078240-saga
# 1821         2542.0  https://www.goodreads.com/book/show/17348705-a...
# 2076          652.0  https://www.goodreads.com/book/show/402114.The...
# _____
#
# Genre 23: ['agent', 'team', 'mission', 'job', 'dead', 'terrorist', 'zombie', 'government', 'secret', 'drug']
#                                                   title  avg_rating  \
# 80    Never Split the Difference: Negotiating As If ...        4.49
# 522                                   Harrison Bergeron        4.23
# 1824  The Match: The Day the Game of Golf Changed Fo...        4.32
# 2238      The Girl Who Played with Fire (Millennium #2)        4.22
# 2478         Shadows for Silence in the Forests of Hell        4.16
# 2586                        The Cartel (The Cartel, #1)        4.58
# 2997                       Hawkeye, Volume 4: Rio Bravo        4.31
# 3201                               Much Obliged, Jeeves        4.24
# 3473              The First Hostage (J. B. Collins, #2)        4.43
#
#       ratings_count                                                url
# 80           3314.0  https://www.goodreads.com/book/show/26156469-n...
# 522         10690.0  https://www.goodreads.com/book/show/10176119-h...
# 1824         1532.0  https://www.goodreads.com/book/show/571428.The...
# 2238         7361.0  https://www.goodreads.com/book/show/6087991-th...
# 2478         5683.0  https://www.goodreads.com/book/show/21411388-s...
# 2586         5703.0  https://www.goodreads.com/book/show/5953477-th...
# 2997         5523.0  https://www.goodreads.com/book/show/22237290-h...
# 3201          472.0  https://www.goodreads.com/book/show/16394.Much...
# 3473         1619.0  https://www.goodreads.com/book/show/26043842-t...
# _____
#
# Genre 20: ['family', 'year', 'child', 'young', 'home', 'past', 'world', 'loss', 'secret', 'friend']
#                                                  title  avg_rating  \
# 85                                       A Little Life        4.28
# 105  Far from the Tree: Parents, Children, and the ...        4.27
# 160  Stars Between the Sun and Moon: One Woman's Li...        4.16
# 170                               The Heart of a Woman        4.19
# 278                                    I Liked My Life        4.21
# 388     Hannah's Gift: Lessons from a Life Fully Lived        4.35
# 514                                   Lament for a Son        4.42
# 536  North of Normal: A Memoir of My Wilderness Chi...        4.16
# 543                   My Lovely Wife in the Psych Ward        4.17
# 559                          All But My Life: A Memoir        4.28
# 573      My Journey : Transforming Dreams into Actions        4.35
# 609  Instrumental: A Memoir of Madness, Medication ...        4.26
# 635                                    After Auschwitz        4.29
# 663                      I Have Lived a Thousand Years        4.16
# 674                              Going to Meet the Man        4.33
# 682  Redefining Realness: My Path to Womanhood, Ide...        4.30
# 693  Carry On, Warrior: The Power of Embracing Your...        4.18
# 795  One Million Lovely Letters: When Life is Looki...        4.19
# 838                  Have a Little Faith: a True Story        4.16
# 908                                     Pastel Orphans        4.23
#
#      ratings_count                                                url
# 85           762.0  https://www.goodreads.com/book/show/29408433-a...
# 105        12131.0  https://www.goodreads.com/book/show/13547504-f...
# 160          451.0  https://www.goodreads.com/book/show/25420166-s...
# 170        16156.0  https://www.goodreads.com/book/show/5160.The_H...
# 278         3450.0  https://www.goodreads.com/book/show/29875926-i...
# 388          868.0  https://www.goodreads.com/book/show/806124.Han...
# 514          974.0  https://www.goodreads.com/book/show/148208.Lam...
# 536         3428.0  https://www.goodreads.com/book/show/18635097-n...
# 543         1215.0  https://www.goodreads.com/book/show/31371250-m...
# 559        14073.0  https://www.goodreads.com/book/show/163363.All...
# 573         1743.0  https://www.goodreads.com/book/show/18371021-m...
# 609         1796.0  https://www.goodreads.com/book/show/21896497-i...
# 635          467.0  https://www.goodreads.com/book/show/17828703-a...
# 663        16409.0  https://www.goodreads.com/book/show/48834.I_Ha...
# 674         3203.0  https://www.goodreads.com/book/show/38469.Goin...
# 682         4581.0  https://www.goodreads.com/book/show/18144031-r...
# 693         2041.0  https://www.goodreads.com/book/show/17138313-c...
# 795          425.0  https://www.goodreads.com/book/show/19862844-o...
# 838        60867.0  https://www.goodreads.com/book/show/1255781.Ha...
# 908         1039.0  https://www.goodreads.com/book/show/24036089-p...
# _____
#
# Genre 7: ['fairy', 'magic', 'adventure', 'world', 'magical', 'die', 'fantasy', 'journey', 'young', 'land']
#                                                   title  avg_rating  \
# 136   The War that Saved My Life (The War That Saved...        4.44
# 142         The Trials of Morrigan Crow (Nevermoor, #1)        4.52
# 511       Mufaro's Beautiful Daughters: An African Tale        4.32
# 731      Grounded: The Adventures of Rapunzel (Tyme #1)        4.16
# 884                    The Complete Grimm's Fairy Tales        4.31
# 1036         The Pillars of the Earth (Kingsbridge, #1)        4.29
# 1079                                     Uncle Dynamite        4.28
# 1464                      Out from Boneville (Bone, #1)        4.16
# 1488                          The First Rumpole Omnibus        4.30
# 1593  J.R.R. Tolkien 4-Book Boxed Set: The Hobbit an...        4.59
# 2130                     Toby Alone (Tobie Lolness, #1)        4.18
# 2148  The Staff of Serapis (Percy Jackson & Kane Chr...        4.31
# 2192                             A Boy Called Christmas        4.25
# 2205  Jaya: An Illustrated Retelling of the Mahabharata        4.20
# 2250                             The Sunne in Splendour        4.40
# 2427  Bridge of Birds (The Chronicles of Master Li a...        4.30
# 2691                                  Pride & Prejudice        4.25
# 2747            The Physician (Cole Family Trilogy, #1)        4.35
# 3098                            Interstellar Cinderella        4.22
# 3177  Alice in Wonderland: Based on the Motion Pictu...        4.19
#
#       ratings_count                                                url
# 136         21307.0  https://www.goodreads.com/book/show/20912424-t...
# 142           754.0  https://www.goodreads.com/book/show/34219873-n...
# 511         16896.0  https://www.goodreads.com/book/show/845403.Muf...
# 731          1438.0  https://www.goodreads.com/book/show/23399287-g...
# 884        117324.0  https://www.goodreads.com/book/show/22917.The_...
# 1036       471990.0  https://www.goodreads.com/book/show/5043.The_P...
# 1079          518.0  https://www.goodreads.com/book/show/16241184-u...
# 1464        63254.0  https://www.goodreads.com/book/show/106134.Out...
# 1488         1278.0  https://www.goodreads.com/book/show/54383.The_...
# 1593        92172.0  https://www.goodreads.com/book/show/30.J_R_R_T...
# 2130         1467.0  https://www.goodreads.com/book/show/2535732.To...
# 2148        12530.0  https://www.goodreads.com/book/show/18752959-t...
# 2192         1471.0  https://www.goodreads.com/book/show/25882558-a...
# 2205         9857.0   https://www.goodreads.com/book/show/9864913-jaya
# 2250        15523.0  https://www.goodreads.com/book/show/119829.The...
# 2427         8063.0  https://www.goodreads.com/book/show/15177.Brid...
# 2691          771.0  https://www.goodreads.com/book/show/6909919-pr...
# 2747        19716.0  https://www.goodreads.com/book/show/4692.The_P...
# 3098         2024.0  https://www.goodreads.com/book/show/22875394-i...
# 3177         2221.0  https://www.goodreads.com/book/show/7052617-al...
# _____
