# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
from scipy import sparse
from sklearn.neighbors import NearestNeighbors
from sklearn.preprocessing import Normalizer
from IPython.display import display
from scipy.sparse.linalg import svds

# %% [markdown]
# ### 0.1 - Load and Prepare Data

# %%
# Load df_books and genres
wd = os.getcwd()
df_books = pd.read_csv(wd + "/data/goodreads_books.csv")
df_inferred_genres = pd.read_csv(wd + "/data/inferred_genres.csv")
genre_descriptors = pd.read_csv(wd + "/data/inferred_genre_top_words.csv")

# Join genres to books
df_books = pd.merge(df_books, df_inferred_genres.drop(columns="title"), how="left", on="book_id")

# %%
# Load sparse_reviews from file
df_reviews = sparse.load_npz(wd + "/data/user_reviews.npz")

# Load user (rows) and book (cols) indices
user_index = pd.read_csv(wd + "/data/user_index_for_sparse_matrix.csv").rename(columns={"0":"user_id"})
book_index = pd.read_csv(wd + "/data/book_index_for_sparse_matrix.csv").rename(columns={"0":"book_id"})

# %%
# Load my goodreads history
my_books = pd.read_csv(wd + "/data/goodreads_library_export.csv")

# Filter to books I've rated
my_books = my_books[["Book Id", "My Rating", "Title"]]\
    .rename(columns={"Book Id":"book_id", "My Rating":"rating", "Title":"title"}).query("rating > 0")
print(f"Target reader ratings: {my_books.shape[0]}")

# Reformat to fit sparse matrix
my_books_1 = pd.merge(
                my_books, df_books[["book_id", "title"]], 
                how="left", on="book_id", suffixes=["_mb","_dfb"]
            )
my_books_id_match = my_books_1[~my_books_1["title_dfb"].isna()]
print(f"Matching on book_id: {my_books_id_match.shape[0]}")

my_books_2 = pd.merge(
    my_books_1[my_books_1["title_dfb"].isna()], df_books[["book_id", "title"]], 
    how="left", left_on="title_mb", right_on="title", suffixes=["_mb","_dfb"]
    )
my_books_match_on_title = my_books_2[~my_books_2["title"].isna()]
print(f"Matching on title: {my_books_match_on_title.shape[0]}")

my_books_id_match = my_books_id_match[["book_id", "rating", "title_dfb"]]\
                        .rename(columns={"title_dfb":"title"})
my_books_match_on_title = my_books_match_on_title[["book_id_dfb", "rating", "title"]]\
                        .rename(columns={"book_id_dfb":"book_id"})

my_books_3 = pd.concat([my_books_id_match, my_books_match_on_title])
my_books_3 = my_books_3.drop_duplicates(subset="book_id")
print(f"Total matches: {my_books_3.shape[0]}, {(my_books_3.shape[0] / my_books.shape[0]):.2%} of total")

my_books_4 = pd.merge(book_index, my_books_3, how="left", on="book_id")#.fillna(0.)
my_books = np.array(my_books_4["rating"]).reshape(1,-1)

# Add to sparse matrix
df_reviews = sparse.vstack([df_reviews, my_books])

# # Normalize reviews within users
# norm = Normalizer()
# df_reviews = norm.fit_transform(df_reviews)
# Out:
# Target reader ratings: 166
# Matching on book_id: 30
# Matching on title: 65
# Total matches: 95, 57.23% of total

# %%
# Set target reader to make recommendations for
target = df_reviews.shape[0] - 1

# %% [markdown]
# #### 0.2 - Functions to Process Recommendations

# %%
# Function to use KNN to find similar users
def find_neighbors(n_neighbors, target_user, ratings_df, ind_books, books):

    # Instantiate KNN
    n_neighbors = n_neighbors

    nn_model = NearestNeighbors(
        metric="cosine",
        algorithm="auto",
        n_neighbors=n_neighbors,
        n_jobs=-1
    )

    # Fit to sparse matrix
    nn_model.fit(ratings_df)

    # Feed in user and get neighbors and distances
    reader = ratings_df[target,:].toarray()
    dists, neighbors = nn_model.kneighbors(reader, return_distance=True)

    similar_users = pd.DataFrame(
        [pd.Series(neighbors.reshape(-1)), pd.Series(dists.reshape(-1))]).T.rename(
            columns={0:"user", 1:"distance"}
    )

    # Get all books read by similar users
    book_ind = []
    book_rat = []
    uid = []
    target_user_books = []
    target_user_book_rat = []
    for nt in similar_users.itertuples():
        user = ratings_df[int(nt.user),:].toarray()
        book_inds = np.where(user[0] > 0)[0]
        ratings = user[0][np.where(user[0] > 0)[0]]
        for i in range(len(book_inds)):        
            book_ind.append(book_inds[i])
            book_rat.append(ratings[i])
            uid.append(nt.user)    
            if nt.distance < 0.000000001:
                target_user_books.append(book_inds[i])
                target_user_book_rat.append(ratings[i])

    neighbor_user_ratings = pd.DataFrame([uid, book_ind, book_rat]).T.rename(
                                columns={0:"uid",1:"book_index",2:"user_rating"}
                            )

    # Join overall rating for each book
    neighbor_user_ratings = pd.merge(
                                ind_books.reset_index(), neighbor_user_ratings, 
                                how="inner", left_on="index", right_on="book_index"
                            )
    neighbor_user_ratings = pd.merge(neighbor_user_ratings, books, how="inner", on="book_id")

    # Filter out books target reader has already read
    neighbor_user_ratings = neighbor_user_ratings[~neighbor_user_ratings["book_index"].isin(target_user_books)]
    neighbor_user_ratings.drop(["index"], axis=1, inplace=True)

    # Filter out later volumes in series using regex pattern
    regex1 = r"#([3-9]|[1-9]\d+)"
    regex2 = r"Vol. ([0-9]|[1-9]\d+)"
    neighbor_user_ratings = neighbor_user_ratings[~neighbor_user_ratings["title"].str.contains(regex1)]
    neighbor_user_ratings = neighbor_user_ratings[~neighbor_user_ratings["title"].str.contains(regex2)]
    neighbor_user_ratings = neighbor_user_ratings[~neighbor_user_ratings["title"].str.contains("#1-")]

    # View target user's ratings
    target_user_ratings = pd.DataFrame(
                            [target_user_books, target_user_book_rat]).T.rename(
                                columns={0:"book_index",1:"user_rating"}
                        )
    target_user_ratings = pd.merge(
                            ind_books.reset_index(), target_user_ratings,
                            how="inner", left_on="index", right_on="book_index"
                        )
    target_user_ratings = pd.merge(target_user_ratings, books, how="inner", on="book_id")    

    return neighbor_user_ratings, target_user_ratings

# %%
# Function to show top recs for each genre
def show_top_recs_by_genre(
        target, others, preds=None, how=["KNN", "MF"], whose_genres=["target", "neighbors"], 
        n_genres=5, min_score=3.9, min_ratings=400, n_recs=15, write_to_excel=False):

    if whose_genres == "target":
        genre_ranking = pd.DataFrame(target.loc[:, "Genre_1":].sum(axis=0).sort_values(ascending=False))
    else:
        genre_ranking = pd.DataFrame(others.loc[:, "Genre_1":].sum(axis=0).sort_values(ascending=False))    
    
    genres = []
    results = []
    # Loop through genres in descending relevance order and print top recs
    for genre in genre_ranking.index[0:n_genres]:        
        
        g = float(genre[6:])
        if how == "KNN":
            highest_rated_recs_genre = others.query("main_genre == @g")\
                .groupby(["title", "avg_rating", "ratings_count", "year", "url"])["book_id"]\
                .count().reset_index().sort_values(by=["avg_rating", "book_id"], ascending=False)
        
        elif how == "MF":
            highest_rated_recs_genre = preds.query("main_genre == @g")\
            .sort_values(by="predicted_rating", ascending=False)                

        highest_rated_recs_genre = highest_rated_recs_genre.query(
                                        "ratings_count > @min_ratings & avg_rating > @min_score"
                                    )

        # Print genre name and descriptor
        for nt in genre_descriptors.itertuples():
            genre_rep = genre.replace("_"," ")
            if nt.genre_string[0:len(f"{genre}:")] == f"{genre_rep}:":
                gs = (nt.genre_string)
        
        genres.append(gs)
        results.append(highest_rated_recs_genre[["title", "avg_rating", "ratings_count", "url"]].head(50))

        print(gs)
        display(highest_rated_recs_genre[["title", "avg_rating", "ratings_count", "url"]].head(n_recs))
        print("_____\n")
    
    # Write to excel if keyword set
    path = (wd + "/data/book_recs.xlsx")
    if write_to_excel == True:
        if os.path.isfile(path):
            with pd.ExcelWriter(path, engine="openpyxl", mode="a", if_sheet_exists='replace') as writer:
                
                pd.DataFrame(genres).rename(columns={0:"Genres"})\
                    .to_excel(writer, sheet_name="Genre Meanings", index=False)
                
                for i in range(len(results)):
                    results[i].to_excel(writer, sheet_name=f"{genres[i].split(':')[0]} Recs", index=False)
        else:
            with pd.ExcelWriter(path) as writer:
                
                pd.DataFrame(genres).rename(columns={0:"Genres"})\
                    .to_excel(writer, sheet_name="Genre Meanings", index=False)
                
                for i in range(len(results)):
                    results[i].to_excel(writer, sheet_name=f"{genres[i].split(':')[0]} Recs", index=False)
        writer.close

# %%
# Functions to show top rated and most popular among similar readers
def neighbors_most_popular(others, n=10, min_ratings=1000, min_score=3.8):
    
    popular_recs = others.query("ratings_count > @min_ratings & avg_rating > @min_score")\
        .groupby(["title", "avg_rating", "ratings_count", "year","url"])["book_id"]\
        .count().reset_index().sort_values(by=["book_id", "avg_rating"], ascending=False)\
        .nlargest(n, "book_id").rename(columns={"book_id":"percent_similar_users_read"})

    popular_recs["percent_similar_users_read"] = (popular_recs["percent_similar_users_read"] / 
                                                    others["uid"].nunique()).map('{:.1%}'.format)
    return popular_recs[["title","avg_rating","ratings_count","year","percent_similar_users_read","url"]]


def neighbors_top_rated(others, n=10, min_ratings=1000, min_score=3.8):

    highest_rated_recs = others.query("ratings_count > @min_ratings & avg_rating > @min_score")\
        .groupby(["title", "avg_rating", "ratings_count", "year","url"])["book_id"]\
        .count().reset_index().sort_values(by=["avg_rating", "book_id"], ascending=False)\
        .nlargest(n, "avg_rating").drop(columns="book_id")

    return highest_rated_recs

# %%
# Function to plot neighbors' and target's top genres
def plot_top_genres(others, target):
    
    fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(12,10))
    neighbor_genre_ranking = pd.DataFrame(others.loc[:, "Genre_1":].sum(axis=0).sort_values(ascending=False))
    target_genre_ranking = pd.DataFrame(target.loc[:, "Genre_1":].sum(axis=0).sort_values(ascending=False))
    
    sns.barplot(
        data=neighbor_genre_ranking, y=neighbor_genre_ranking.index, x=0, ax=ax[0]
    )
    ax[0].set_xlabel("Genre preference")
    ax[0].set_title("Neighbors' Top Genres")

    # Plot target reader's top genres    
    sns.barplot(
        data=target_genre_ranking, y=target_genre_ranking.index, x=0, ax=ax[1]
    )
    ax[1].set_xlabel("Genre preference")
    ax[1].set_title("Target User's Top Genres")
    
    plt.show()

# %% [markdown]
# ## TESTING using gradient descent for matrix factorization

# %%
# Find larger number of similar users than before to get broad pool of potentially relevant books
df_reviews.data[np.isnan(df_reviews.data)] = 0
df_reviews = sparse.csr_matrix(df_reviews)
large_neighborhood_ratings, target_user_ratings = find_neighbors(500, target, df_reviews, book_index, df_books)

# Get unique users and books to slice df_reviews
neighbor_index = large_neighborhood_ratings["uid"].unique()
neighbor_index = np.append(neighbor_index, target)
neighbor_book_index = large_neighborhood_ratings["book_index"].unique()
neighbor_book_index = np.append(neighbor_book_index, target_user_ratings["book_index"].unique())

# Slice df_reviews to make User Ratings Matrix
df_reviews.data[df_reviews.data == 0] = np.nan
df_reviews = sparse.csr_matrix(df_reviews)
R = df_reviews[:, neighbor_book_index]
R = R[neighbor_index, :].toarray()
# Out:
# /var/folders/hf/1k3w_wb93bd1yp7b5_jh65mw0000gn/T/ipykernel_14241/903381106.py:62: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   neighbor_user_ratings = neighbor_user_ratings[~neighbor_user_ratings["title"].str.contains(regex1)]
# /var/folders/hf/1k3w_wb93bd1yp7b5_jh65mw0000gn/T/ipykernel_14241/903381106.py:63: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   neighbor_user_ratings = neighbor_user_ratings[~neighbor_user_ratings["title"].str.contains(regex2)]

# %%
# def matrix_factorization1(R, k=5, steps=4000, lr=0.0002, beta=0.02, verbose=0):
#     """
#     Uses gradient descent to train matrix factorization algorithm. Useful explanation
#     of the math here: 
#     http://www.quuxlabs.com/blog/2010/09/matrix-factorization-a-simple-tutorial-and-implementation-in-python/#source-code

#     Args:
#         R: Utility matrix of user item ratings         
#         k: Number of latent features
#         steps: Number of epochs to run training
#         lr: Learning rate
#         beta: Regularization strength
#         verbose: Prints updates if 1

#     Returns:
#         Predictions, User Embeddings, Item Embdeddings
#     """
#     # Initialize random values for user (P) and book (Q) embedding matrices
#     P = np.random.rand(R.shape[0],K)
#     Q = np.random.rand(R.shape[1],K).T
    
#     for step in range(steps): # For each steps
#         r_0 = np.where(R > 0) # Find indices where rating > 0
#         e = 0 # Initialize error for step to 0
#         for n in range(len(r_0[0])): # For each value where rating > 0
#             i = r_0[0][n] # Get the row index where the value is
#             j = r_0[1][n] # Get the column index where the value is
#             resid = R[i][j] - np.dot(P[i,:],Q[:,j]) # residual is value - r_hat
#             e = e + pow(R[i][j] - np.dot(P[i,:],Q[:,j]), 2) # Add to error
#             for k in range(K): # for each component (latent feature)       
#                 P[i][k] = P[i][k] + lr * (2 * resid * Q[k][j] - beta * P[i][k]) # Update P by step in gradient
#                 Q[k][j] = Q[k][j] + lr * (2 * resid * P[i][k] - beta * Q[k][j]) # Update Q by step in gradient
#                 e = e + (beta/2) * (pow(P[i][k],2) + pow(Q[k][j],2)) # Update error with regularized term

#         # View progress
#         if verbose == 1:
#             if step % (steps / 10) == 0:
#                 print(f"Step: {step}, error: {e}")
        
#         # Break loop if error is very small
#         if e < 0.001:
#             break
    
#     # Get predictions
#     preds = np.dot(P, Q)

#     return preds, P, Q.T

# %%
# Function to train embedding matrices using alternating least squares (ALS) and make predictions 
def matrix_factorization(R, k_components=5, steps=4000, lr=0.0002, beta=0.05, decay=0.95, verbose=0):
    """
    Uses gradient descent to train matrix factorization algorithm. Useful explanation
    of the math here: 
    http://www.quuxlabs.com/blog/2010/09/matrix-factorization-a-simple-tutorial-and-implementation-in-python/#source-code

    Args:
        R: Utility matrix of user item ratings         
        k: Number of latent features
        steps: Number of epochs to run training
        lr: Learning rate
        beta: Regularization strength
        verbose: Prints updates if 1

    Returns:
        Predictions, User Embeddings, Item Embdeddings
    """

    # Initialize random values for user (P) and book (Q) embedding matrices    
    P = np.random.rand(R.shape[0],k_components)
    Q = np.random.rand(R.shape[1],k_components).T

    # Get nonzero ratings to perform operations on
    r_0 = np.where(R > 0) # Find indices where rating > 0
    i = r_0[0] # Get row indices where rating > 0
    j = r_0[1] # Get column indices where rating > 0 
    nonzero_ratings = R[i,j]

    # For each step calc residual and take step down gradient
    for step in range(steps): 
        resid = nonzero_ratings - (P @ Q)[i,j] # residual is value - r_hat       
        for k in range(k_components): # for each component (latent feature)                
            P[i,k] = P[i,k] + lr * (2 * resid * Q[k,j] - beta * P[i,k]) # Update P by step in gradient                             
            Q[k,j] = Q[k,j] + lr * (2 * resid * P[i,k] - beta * Q[k,j]) # Update Q by step in gradient    

        # Calculate error every 1k steps                  
        if ((step + 1) % 1000 == 0) | (step == 0): # Only do every 1k steps
            error = 0 # Initialize counter for error  
            error = error + np.sum(pow(resid, 2)) # Add to error
            for k in range(k_components): # for each component (latent feature)                             
                error = error + (beta/2) * np.sum(pow(P[i,k],2) + pow(Q[k,j],2)) # Add regularized term 

            # View progress
            if verbose == 1:
                print(f"Step: {step + 1}, error: {error:.2f}, lr: {lr:.6f}") 
            
            # Set learning rate to decay until 0.00002
            if lr > 0.00002:            
                # lr = (1 / (1 + decay * (step))) * lr 
                lr = lr * decay
    
    # Get predictions
    preds = np.dot(P, Q)

    return preds, P, Q.T

# %%
preds, user_embeddings, item_embeddings = matrix_factorization(R, k_components=100, lr=0.0005, beta=0.1, steps=10000, verbose=1)
# Out:
# Step: 1, error: 1099942.36, lr: 0.000500
# Step: 1000, error: 9569.98, lr: 0.000475
# Step: 2000, error: 8224.36, lr: 0.000451
# Step: 3000, error: 7153.62, lr: 0.000429
# Step: 4000, error: 6294.24, lr: 0.000407
# Step: 5000, error: 5598.85, lr: 0.000387
# Step: 6000, error: 5031.78, lr: 0.000368
# Step: 7000, error: 4565.95, lr: 0.000349
# Step: 8000, error: 4180.60, lr: 0.000332
# Step: 9000, error: 3859.71, lr: 0.000315
# Step: 10000, error: 3590.82, lr: 0.000299

# %%
# Make dataframe from predictions and indices
df_preds = pd.DataFrame(preds, columns=neighbor_book_index, index=neighbor_index)\
                .reset_index()

# Get target user's top predicted ratings
target_pred_books = df_preds[df_preds["index"] == target].columns[1:]
target_pred_ratings = df_preds[df_preds["index"] == target].values[0][1:]

# Put into df with relevant info from df_books
top_preds = pd.DataFrame({"book_index":target_pred_books, "predicted_rating":target_pred_ratings})\
                .sort_values(by="predicted_rating", ascending=False)\
                .merge(book_index.reset_index(), left_on="book_index", right_on="index")\
                .merge(
                    df_books[["book_id", "title", "avg_rating", "ratings_count", "year", "main_genre","url"]],
                    on="book_id"
                )\
                .drop(columns=["index"])

# View preds on actually read books
target_books_preds = top_preds[top_preds["book_index"].isin(target_user_ratings["book_index"].unique())]\
                        .drop(["book_index"], axis=1)
target_books_preds = pd.merge(target_books_preds, target_user_ratings[["book_id", "user_rating"]], on="book_id")
target_books_preds["diff"] = target_books_preds["predicted_rating"] - target_books_preds["user_rating"]
print("Predictions on Actually Read Books")
display(target_books_preds[["title", "predicted_rating", "user_rating", "diff"]])

# Filter out already read books to get top preds
print("___________\n")
print("Predictions on Unread Books")
top_preds = top_preds[~top_preds["book_index"].isin(target_user_ratings["book_index"].unique())]
display(top_preds[["title","avg_rating","predicted_rating","ratings_count","year","url"]]\
        .query("avg_rating > 3.9").head(20)
    )
# Out:
# Predictions on Actually Read Books
#                                                 title  predicted_rating  \
# 0                            Miles: The Autobiography          4.963302
# 1   The Devil's Chessboard: Allen Dulles, the CIA,...          4.963243
# 2             The Fifth Season (The Broken Earth, #1)          4.963189
# 3               Sapiens: A Brief History of Humankind          4.963188
# 4   Born a Crime: Stories From a South African Chi...          4.963179
# ..                                                ...               ...
# 90                     Fear and Loathing in Las Vegas          1.985985
# 91                                    The Sympathizer          1.985964
# 92  The One Thing: The Surprisingly Simple Truth B...          1.985950
# 93                     Casino Royale (James Bond, #1)          0.995555
# 94  Hillbilly Elegy: A Memoir of a Family and Cult...          0.993763
#
#     user_rating      diff
# 0           5.0 -0.036698
# 1           5.0 -0.036757
# 2           5.0 -0.036811
# 3           5.0 -0.036812
# 4           5.0 -0.036821
# ..          ...       ...
# 90          2.0 -0.014015
# 91          2.0 -0.014036
# 92          2.0 -0.014050
# 93          1.0 -0.004445
# 94          1.0 -0.006237
#
# [95 rows x 4 columns]
# ___________
#
# Predictions on Unread Books
#                                                 title  avg_rating  \
# 0   Story Genius: How to Use Brain Science to Go B...        4.28
# 4                  All Who Go Do Not Return: A Memoir        4.22
# 5                                          Incidences        4.32
# 6   Parliament of Whores: A Lone Humorist Attempts...        4.02
# 7                              The Elephant Whisperer        4.44
# 8                          Gateway (Heechee Saga, #1)        4.07
# 9                            City of Saints & Thieves        3.95
# 11  Alice in Wonderland and the World Trade Center...        3.97
# 12                                 Teach Me to Forget        3.94
# 13  Option B: Facing Adversity, Building Resilienc...        3.94
# 18                                     Shades of Grey        4.14
# 21                                    Deep Dark Fears        4.05
# 22                                Sure Signs of Crazy        3.94
# 23  The Shock Doctrine: The Rise of Disaster Capit...        4.23
# 24  The Unreal and the Real: Selected Stories, Vol...        4.23
# 25  The Power of Ashtanga Yoga: Developing a Pract...        4.35
# 27                  The Distance Between Us: A Memoir        4.19
# 28                            The Chronology of Water        4.20
# 32                                 If I Was Your Girl        4.03
# 34  The Norton Anthology of American Literature, S...        4.01
#
#     predicted_rating  ratings_count  year  \
# 0           8.658874          385.0  2016
# 4           8.259791         1980.0  2015
# 5           8.201976          658.0  2007
# 6           8.190287         2569.0  1991
# 7           8.100394         6905.0  2009
# 8           8.099785        30282.0  2004
# 9           8.066592         1705.0  2017
# 11          8.018390          241.0  2002
# 12          7.951542          817.0  2016
# 13          7.910342        14348.0  2017
# 18          7.844304        23122.0  2009
# 21          7.744760         1734.0  2015
# 22          7.737356         2462.0  2013
# 23          7.722670          664.0  2008
# 24          7.717945          459.0  2012
# 25          7.680235          304.0  2013
# 27          7.667765          171.0  2013
# 28          7.634909         4956.0  2011
# 32          7.616873          872.0  2016
# 34          7.610981          350.0  2003
#
#                                                   url
# 0   https://www.goodreads.com/book/show/27833542-s...
# 4   https://www.goodreads.com/book/show/22244929-a...
# 5   https://www.goodreads.com/book/show/685172.Inc...
# 6   https://www.goodreads.com/book/show/44781.Parl...
# 7   https://www.goodreads.com/book/show/6375561-th...
# 8   https://www.goodreads.com/book/show/218427.Gat...
# 9   https://www.goodreads.com/book/show/33956433-c...
# 11  https://www.goodreads.com/book/show/240887.Ali...
# 12  https://www.goodreads.com/book/show/29526341-t...
# 13  https://www.goodreads.com/book/show/32938155-o...
# 18  https://www.goodreads.com/book/show/2113260.Sh...
# 21  https://www.goodreads.com/book/show/24388442-d...
# 22  https://www.goodreads.com/book/show/16131070-s...
# 23  https://www.goodreads.com/book/show/2171147.Th...
# 24  https://www.goodreads.com/book/show/13591879-t...
# 25  https://www.goodreads.com/book/show/15798826-t...
# 27  https://www.goodreads.com/book/show/15015046-t...
# 28  https://www.goodreads.com/book/show/9214995-th...
# 32  https://www.goodreads.com/book/show/29470648-i...
# 34  https://www.goodreads.com/book/show/47160.The_...

# %%
# Highest rated books by each of the top genres
show_top_recs_by_genre(
    target_user_ratings, 
    large_neighborhood_ratings, 
    preds=top_preds, 
    how="MF", 
    whose_genres="target", 
    n_genres=10, 
    min_score=4.15, 
    min_ratings=400, 
    n_recs=20,
    write_to_excel=False
)
# Out:
# Genre 5: ['history', 'war', 'political', 'account', 'world', 'year', 'country', 'family', 'century', 'people']
#                                                  title  avg_rating  \
# 126         Daring to Drive: A Saudi Woman’s Awakening        4.32
# 140  The Girl with Seven Names: A North Korean Defe...        4.45
# 148  Ratf**ked: The True Story Behind The Secret Pl...        4.16
# 164              American Tabloid (Underworld USA, #1)        4.21
# 190                                  A Fighting Chance        4.17
# 196                                 Fortune is a Woman        4.21
# 204         The Silk Roads: A New History of the World        4.25
# 231  Arch of Triumph: A Novel of a Man Without a Co...        4.40
# 290                                               Open        4.18
# 291                             The Great Dune Trilogy        4.36
# 296            Top Dog: The Story of Marine Hero Lucca        4.34
# 307  No Ordinary Time: Franklin and Eleanor Rooseve...        4.19
# 319                                           Pachinko        4.18
# 321   Indonesia, Etc.: Exploring the Improbable Nation        4.18
# 345  Get Well Soon: History's Worst Plagues and the...        4.24
# 356                                Auschwitz and After        4.35
# 367  The New Jim Crow: Mass Incarceration in the Ag...        4.49
# 390             Our Revolution: A Future to Believe In        4.29
# 412          Shoe Dog: A Memoir by the Creator of NIKE        4.44
# 439  Digital Gold: Bitcoin and the Inside Story of ...        4.16
#
#      ratings_count                                                url
# 126          871.0  https://www.goodreads.com/book/show/32620356-d...
# 140         8293.0  https://www.goodreads.com/book/show/25362017-t...
# 148          438.0  https://www.goodreads.com/book/show/26889647-r...
# 164        10342.0  https://www.goodreads.com/book/show/36064.Amer...
# 190         8740.0  https://www.goodreads.com/book/show/18779662-a...
# 196          992.0  https://www.goodreads.com/book/show/355715.For...
# 204         3022.0  https://www.goodreads.com/book/show/25812847-t...
# 231        11703.0  https://www.goodreads.com/book/show/672948.Arc...
# 290        48230.0   https://www.goodreads.com/book/show/6480781-open
# 291        52034.0  https://www.goodreads.com/book/show/53764.The_...
# 296          505.0  https://www.goodreads.com/book/show/20893379-t...
# 307        28368.0  https://www.goodreads.com/book/show/18728.No_O...
# 319         8161.0  https://www.goodreads.com/book/show/29983711-p...
# 321          470.0  https://www.goodreads.com/book/show/18377963-i...
# 345         1163.0  https://www.goodreads.com/book/show/30199426-g...
# 356          758.0  https://www.goodreads.com/book/show/339757.Aus...
# 367        24694.0  https://www.goodreads.com/book/show/6792458-th...
# 390         2430.0  https://www.goodreads.com/book/show/31741420-o...
# 412        27468.0  https://www.goodreads.com/book/show/27220736-s...
# 439         1674.0  https://www.goodreads.com/book/show/23546676-d...
# _____
#
# Genre 15: ['history', 'poem', 'essay', 'text', 'century', 'collection', 'world', 'writing', 'introduction', 'literature']
#                                                  title  avg_rating  \
# 24   The Unreal and the Real: Selected Stories, Vol...        4.23
# 73       Natasha's Dance: A Cultural History of Russia        4.16
# 77            Sounds Like Me: My Life (So Far) in Song        4.26
# 106  Collected Writings: Common Sense/The Crisis/Ri...        4.24
# 149  Woman in the Mists: The Story of Dian Fossey a...        4.16
# 194  Notes from Underground, White Nights, The Drea...        4.17
# 245                                          Mama Ruby        4.25
# 248                          Her Smoke Rose Up Forever        4.22
# 295          Gaviotas: A Village to Reinvent the World        4.17
# 346  The World of Ice & Fire: The Untold History of...        4.26
# 352                                                Nox        4.30
# 364  Faraday, Maxwell, and the Electromagnetic Fiel...        4.24
# 398  The Fire This Time: A New Generation Speaks ab...        4.35
# 487  The World According to Mister Rogers: Importan...        4.32
# 569  Surely You're Joking, Mr. Feynman!: Adventures...        4.29
# 611                         We Should All Be Feminists        4.47
# 829                          Gitanjali: Song Offerings        4.33
# 911  The Truth: An Uncomfortable Book About Relatio...        4.20
# 923                                       The Way I Am        4.30
# 947                            The Laugh of the Medusa        4.16
#
#      ratings_count                                                url
# 24           459.0  https://www.goodreads.com/book/show/13591879-t...
# 73          2039.0  https://www.goodreads.com/book/show/97401.Nata...
# 77          3867.0  https://www.goodreads.com/book/show/25434361-s...
# 106         1503.0  https://www.goodreads.com/book/show/99953.Coll...
# 149         2955.0  https://www.goodreads.com/book/show/546693.Wom...
# 194        66680.0  https://www.goodreads.com/book/show/17876.Note...
# 245         1376.0  https://www.goodreads.com/book/show/9475835-ma...
# 248         2539.0  https://www.goodreads.com/book/show/27059.Her_...
# 295          555.0  https://www.goodreads.com/book/show/136893.Gav...
# 346        12952.0  https://www.goodreads.com/book/show/17345242-t...
# 352         2034.0    https://www.goodreads.com/book/show/7428663-nox
# 364          431.0  https://www.goodreads.com/book/show/18240286-f...
# 398         2309.0  https://www.goodreads.com/book/show/28505023-t...
# 487         1795.0  https://www.goodreads.com/book/show/73123.The_...
# 569        95353.0  https://www.goodreads.com/book/show/5544.Surel...
# 611         1351.0  https://www.goodreads.com/book/show/23301818-w...
# 829         4835.0  https://www.goodreads.com/book/show/66414.Gita...
# 911         2503.0  https://www.goodreads.com/book/show/26887738-t...
# 923         1576.0  https://www.goodreads.com/book/show/3295736-th...
# 947          752.0  https://www.goodreads.com/book/show/11080013-t...
# _____
#
# Genre 17: ['alien', 'planet', 'world', 'human', 'ship', 'space', 'war', 'crew', 'mission', 'race']
#                                                   title  avg_rating  \
# 90                 Spellbound (Grimnoir Chronicles, #2)        4.29
# 159                     Wolf by Wolf (Wolf by Wolf, #1)        4.28
# 303   Foundation / Foundation and Empire / Second Fo...        4.35
# 338                               The Evolutionary Void        4.26
# 372   The Last Rhinos: My Battle to Save One of the ...        4.34
# 385   The Deep: The Extraordinary Creatures of the A...        4.28
# 648                        Leviathan Wakes (Expanse #1)        4.20
# 866   The Hyperion Omnibus: Hyperion / The Fall of H...        4.41
# 876   Deep: Freediving, Renegade Science, and What t...        4.40
# 898                     Caliban's War (The Expanse, #2)        4.29
# 1096                            The Abyss Beyond Dreams        4.21
# 1134                   Kings of the Wyld (The Band, #1)        4.42
# 1251  Spillover: Animal Infections and the Next Huma...        4.27
# 1340      The Ultimate Hitchhiker's Guide to the Galaxy        4.38
# 1442                                       Star Wars #1        4.17
# 1643                              I, Robot (Robot #0.1)        4.17
#
#       ratings_count                                                url
# 90           7184.0  https://www.goodreads.com/book/show/10822283-s...
# 159          9710.0  https://www.goodreads.com/book/show/24807186-w...
# 303          3316.0  https://www.goodreads.com/book/show/278097.Fou...
# 338         13729.0  https://www.goodreads.com/book/show/7438179-th...
# 372          1094.0  https://www.goodreads.com/book/show/13167157-t...
# 385           901.0  https://www.goodreads.com/book/show/442668.The...
# 648          1998.0  https://www.goodreads.com/book/show/9533361-le...
# 866          2254.0  https://www.goodreads.com/book/show/3943.The_H...
# 876          1144.0  https://www.goodreads.com/book/show/18222705-deep
# 898         41459.0  https://www.goodreads.com/book/show/12591698-c...
# 1096         4944.0  https://www.goodreads.com/book/show/20697413-t...
# 1134         2285.0  https://www.goodreads.com/book/show/30841984-k...
# 1251         2586.0  https://www.goodreads.com/book/show/13637215-s...
# 1340       225626.0  https://www.goodreads.com/book/show/13.The_Ult...
# 1442         1109.0  https://www.goodreads.com/book/show/24496462-s...
# 1643       201196.0  https://www.goodreads.com/book/show/41804.I_Robot
# _____
#
# Genre 8: ['guide', 'people', 'way', 'help', 'practical', 'world', 'experience', 'offer', 'question', 'business']
#                                                  title  avg_rating  \
# 23   The Shock Doctrine: The Rise of Disaster Capit...        4.23
# 39   Autism's False Prophets: Bad Science, Risky Me...        4.18
# 46   The (7L) The Seven Levels of Communication: Go...        4.33
# 47   The Book on the Taboo Against Knowing Who You Are        4.28
# 59   There Is No Good Card for This: What To Say an...        4.31
# 99   Algorithms to Live By: The Computer Science of...        4.16
# 165  Ready to Run: Unlocking Your Potential to Run ...        4.29
# 176  The Power of Vulnerability: Teachings of Authe...        4.57
# 239              Calm: Calm the Mind. Change the World        4.17
# 241                                              Impro        4.27
# 260  The Healing of America: A Global Quest for Bet...        4.22
# 304  The Big Fat Surprise: Why Butter, Meat and Che...        4.25
# 318  Mountains Beyond Mountains: The Quest of Dr. P...        4.21
# 378  The Hard Thing About Hard Things: Building a B...        4.20
# 486                      Thinking in Systems: A Primer        4.24
# 516                        The Science of Interstellar        4.19
# 549  Radical Acceptance: Embracing Your Life With t...        4.25
# 594  The Book of Joy: Lasting Happiness in a Changi...        4.34
# 628  How to Raise an Adult: Break Free of the Overp...        4.17
# 690                             High Output Management        4.37
#
#      ratings_count                                                url
# 23           664.0  https://www.goodreads.com/book/show/2171147.Th...
# 39           987.0  https://www.goodreads.com/book/show/3360358-au...
# 46           482.0  https://www.goodreads.com/book/show/9858250-th...
# 47         10108.0  https://www.goodreads.com/book/show/60551.The_...
# 59           547.0  https://www.goodreads.com/book/show/28257714-t...
# 99          4639.0  https://www.goodreads.com/book/show/25666050-a...
# 165          772.0  https://www.goodreads.com/book/show/18668429-r...
# 176         3778.0  https://www.goodreads.com/book/show/23500254-t...
# 239          580.0  https://www.goodreads.com/book/show/25194140-calm
# 241         1653.0   https://www.goodreads.com/book/show/306940.Impro
# 260         4086.0  https://www.goodreads.com/book/show/6402544-th...
# 304         2157.0  https://www.goodreads.com/book/show/16130316-t...
# 318        53936.0  https://www.goodreads.com/book/show/10235.Moun...
# 378        20745.0  https://www.goodreads.com/book/show/18176747-t...
# 486         3011.0  https://www.goodreads.com/book/show/3828902-th...
# 516         2331.0  https://www.goodreads.com/book/show/23261448-t...
# 549         8593.0  https://www.goodreads.com/book/show/173666.Rad...
# 594         9067.0  https://www.goodreads.com/book/show/29496453-t...
# 628         2892.0  https://www.goodreads.com/book/show/23168823-h...
# 690         2883.0  https://www.goodreads.com/book/show/324750.Hig...
# _____
#
# Genre 11: ['fiction', 'collection', 'world', 'literary', 'young', 'funny', 'short', 'comedy', 'horror', 'debut']
#                                                   title  avg_rating  \
# 5                                            Incidences        4.32
# 138                                      Asterios Polyp        4.19
# 267       A Manual for Cleaning Women: Selected Stories        4.17
# 400   A Supposedly Fun Thing I'll Never Do Again:  E...        4.28
# 556   Sherlock Holmes: The Complete Novels and Stori...        4.45
# 1289               The Essential Dykes to Watch Out For        4.36
# 1349  Beautiful Outlaw: Experiencing the Playful, Di...        4.31
#
#       ratings_count                                                url
# 5             658.0  https://www.goodreads.com/book/show/685172.Inc...
# 138         20053.0  https://www.goodreads.com/book/show/4070095-as...
# 267          6863.0  https://www.goodreads.com/book/show/22929586-a...
# 400         23746.0  https://www.goodreads.com/book/show/6748.A_Sup...
# 556         18729.0  https://www.goodreads.com/book/show/3581.Sherl...
# 1289         6979.0  https://www.goodreads.com/book/show/3189884-th...
# 1349         2633.0  https://www.goodreads.com/book/show/12079560-b...
# _____
#
# Genre 22: ['world', 'power', 'enemy', 'war', 'battle', 'evil', 'magic', 'save', 'ancient', 'warrior']
#                                                   title  avg_rating  \
# 69    The Sword of Summer (Magnus Chase and The Gods...        4.26
# 123                        Legend (The Drenai Saga, #1)        4.25
# 137            Lost Boy: The True Story of Captain Hook        4.20
# 157                       The Last Namsara (Iskari, #1)        4.25
# 288                           Everwild (Skinjacker, #2)        4.21
# 312   When Christ and His Saints Slept  (Henry II an...        4.27
# 329                 Rebel Spring (Falling Kingdoms, #2)        4.16
# 341                                          The Cartel        4.29
# 363   The Hammer of Thor (Magnus Chase and the Gods ...        4.37
# 443   Time and Chance (Henry II & Eleanor of Aquitai...        4.28
# 503                         Blackwing (Ravens' Mark #1)        4.24
# 625                               Villains by Necessity        4.19
# 644        The False Prince (The Ascendance Trilogy #1)        4.23
# 658      A Clash of Kings  (A Song of Ice and Fire, #2)        4.40
# 696                     The Final Empire (Mistborn, #1)        4.43
# 792                      Thrawn (Star Wars: Thrawn, #1)        4.30
# 843   Age of Myth (The Legends of the First Empire, #1)        4.27
# 945                   Dawn of Wonder (The Wakening, #1)        4.35
# 958                The Stonekeeper's Curse (Amulet, #2)        4.33
# 1078    Split the Party (Spells, Swords, & Stealth, #2)        4.25
#
#       ratings_count                                                url
# 69            921.0  https://www.goodreads.com/book/show/25909686-t...
# 123         18805.0  https://www.goodreads.com/book/show/618177.Legend
# 137          1420.0  https://www.goodreads.com/book/show/32828538-l...
# 157           865.0  https://www.goodreads.com/book/show/32667458-t...
# 288          9779.0  https://www.goodreads.com/book/show/6390465-ev...
# 312         10892.0  https://www.goodreads.com/book/show/43841.When...
# 329           521.0  https://www.goodreads.com/book/show/18668021-r...
# 341          9961.0  https://www.goodreads.com/book/show/23602561-t...
# 363         26454.0  https://www.goodreads.com/book/show/27904311-t...
# 443          6106.0  https://www.goodreads.com/book/show/234560.Tim...
# 503           401.0  https://www.goodreads.com/book/show/33916060-b...
# 625          1116.0  https://www.goodreads.com/book/show/401454.Vil...
# 644         51292.0  https://www.goodreads.com/book/show/12432220-t...
# 658        534960.0  https://www.goodreads.com/book/show/10572.A_Cl...
# 696          2140.0  https://www.goodreads.com/book/show/12968705-t...
# 792          5220.0  https://www.goodreads.com/book/show/31140332-t...
# 843          9328.0  https://www.goodreads.com/book/show/26863057-a...
# 945         13351.0  https://www.goodreads.com/book/show/25451852-d...
# 958         22479.0  https://www.goodreads.com/book/show/6277410-th...
# 1078         2062.0  https://www.goodreads.com/book/show/25920141-s...
# _____
#
# Genre 3: ['collection', 'comic', 'short', 'fan', 'feature', 'bestselling', 'adventure', 'available', 'classic', 'includes']
#                                                   title  avg_rating  \
# 71        Y: The Last Man - The Deluxe Edition Book One        4.36
# 215   Walt Disney Imagineering: A Behind the Dreams ...        4.23
# 221        A Good Man is Hard to Find and Other Stories        4.24
# 237                                   Calvin and Hobbes        4.61
# 266   A History of the English Speaking Peoples, 4 Vols        4.31
# 376                                 The Paper Menagerie        4.37
# 399                 Adventure Time With Fionna and Cake        4.41
# 455                                      Saga: Book One        4.70
# 513   The Complete Clive Barker's The Great And Secr...        4.21
# 522      Harry Potter: The Prequel (Harry Potter, #0.5)        4.22
# 537                     The Mysteries of Harris Burdick        4.53
# 543   Tales of the Peculiar (Miss Peregrine's Peculi...        4.17
# 737                              Make Way for Ducklings        4.22
# 833                      The Kite Runner: Graphic Novel        4.25
# 875                                              Nimona        4.20
# 1043                                 The Complete Tales        4.36
# 1301  The Glory of Their Times: The Story of the Ear...        4.32
#
#       ratings_count                                                url
# 71          10549.0      https://www.goodreads.com/book/show/3710603-y
# 215          1279.0  https://www.goodreads.com/book/show/380248.Wal...
# 221         26384.0  https://www.goodreads.com/book/show/48464.A_Go...
# 237        120371.0  https://www.goodreads.com/book/show/77727.Calv...
# 266           767.0  https://www.goodreads.com/book/show/1644043.A_...
# 376          2476.0  https://www.goodreads.com/book/show/13501210-t...
# 399          2542.0  https://www.goodreads.com/book/show/17348705-a...
# 455          4201.0  https://www.goodreads.com/book/show/22078240-saga
# 513         15868.0  https://www.goodreads.com/book/show/34871.The_...
# 522         13267.0  https://www.goodreads.com/book/show/8933944-ha...
# 537           652.0  https://www.goodreads.com/book/show/402114.The...
# 543         10785.0  https://www.goodreads.com/book/show/29358487-t...
# 737         71133.0  https://www.goodreads.com/book/show/29291.Make...
# 833          6466.0  https://www.goodreads.com/book/show/11296523-t...
# 875          3222.0  https://www.goodreads.com/book/show/23131088-n...
# 1043        57602.0  https://www.goodreads.com/book/show/19330.The_...
# 1301         3025.0  https://www.goodreads.com/book/show/461749.The...
# _____
#
# Genre 23: ['agent', 'team', 'mission', 'job', 'dead', 'terrorist', 'zombie', 'government', 'secret', 'drug']
#                                           title  avg_rating  ratings_count  \
# 615  Shadows for Silence in the Forests of Hell        4.16         5683.0
# 708                           Harrison Bergeron        4.23        10690.0
# 758                 The Cartel (The Cartel, #1)        4.58         5703.0
#
#                                                    url
# 615  https://www.goodreads.com/book/show/21411388-s...
# 708  https://www.goodreads.com/book/show/10176119-h...
# 758  https://www.goodreads.com/book/show/5953477-th...
# _____
#
# Genre 20: ['family', 'year', 'child', 'young', 'home', 'past', 'world', 'loss', 'secret', 'friend']
#                                                  title  avg_rating  \
# 4                   All Who Go Do Not Return: A Memoir        4.22
# 28                             The Chronology of Water        4.20
# 91                                    Lament for a Son        4.42
# 191  Far from the Tree: Parents, Children, and the ...        4.27
# 268                                    I Liked My Life        4.21
# 384  These Is My Words: The Diary of Sarah Agnes Pr...        4.34
# 411                      Murderville (Murderville, #1)        4.57
# 433                                Good Night, Mr. Tom        4.28
# 482                      I Have Lived a Thousand Years        4.16
# 528                The Outside Circle: A Graphic Novel        4.23
# 551                               The Best We Could Do        4.39
# 580                    Hum If You Don’t Know the Words        4.22
# 703                   My Lovely Wife in the Psych Ward        4.17
# 755                   Ghost Stories (Essex County, #2)        4.20
# 763  Stars Between the Sun and Moon: One Woman's Li...        4.16
# 767                                      Rising Strong        4.19
# 825  Redefining Realness: My Path to Womanhood, Ide...        4.30
# 856                               The Heart of a Woman        4.19
# 871      My Journey : Transforming Dreams into Actions        4.35
# 892  Maus II: A Survivor's Tale: And Here My Troubl...        4.40
#
#      ratings_count                                                url
# 4           1980.0  https://www.goodreads.com/book/show/22244929-a...
# 28          4956.0  https://www.goodreads.com/book/show/9214995-th...
# 91           974.0  https://www.goodreads.com/book/show/148208.Lam...
# 191        12131.0  https://www.goodreads.com/book/show/13547504-f...
# 268         3450.0  https://www.goodreads.com/book/show/29875926-i...
# 384        44889.0  https://www.goodreads.com/book/show/348225.The...
# 411         2120.0  https://www.goodreads.com/book/show/9805946-mu...
# 433        25271.0  https://www.goodreads.com/book/show/161099.Goo...
# 482        16409.0  https://www.goodreads.com/book/show/48834.I_Ha...
# 528          875.0  https://www.goodreads.com/book/show/23130299-t...
# 551         2485.0  https://www.goodreads.com/book/show/29936927-t...
# 580          971.0  https://www.goodreads.com/book/show/28264701-h...
# 703         1215.0  https://www.goodreads.com/book/show/31371250-m...
# 755          953.0  https://www.goodreads.com/book/show/1101110.Es...
# 763          451.0  https://www.goodreads.com/book/show/25420166-s...
# 767        23667.0  https://www.goodreads.com/book/show/23317538-r...
# 825         4581.0  https://www.goodreads.com/book/show/18144031-r...
# 856        16156.0  https://www.goodreads.com/book/show/5160.The_H...
# 871         1743.0  https://www.goodreads.com/book/show/18371021-m...
# 892        93669.0  https://www.goodreads.com/book/show/15197.Maus_II
# _____
#
# Genre 7: ['fairy', 'magic', 'adventure', 'world', 'magical', 'die', 'fantasy', 'journey', 'young', 'land']
#                                                   title  avg_rating  \
# 80        Mufaro's Beautiful Daughters: An African Tale        4.32
# 299   The War that Saved My Life (The War That Saved...        4.44
# 300                           The First Rumpole Omnibus        4.30
# 322                                      Uncle Dynamite        4.28
# 612          The Pillars of the Earth (Kingsbridge, #1)        4.29
# 704   Bridge of Birds (The Chronicles of Master Li a...        4.30
# 1075                     Toby Alone (Tobie Lolness, #1)        4.18
# 1129  Alice in Wonderland: Based on the Motion Pictu...        4.19
# 1520  The Lion, the Witch, and the Wardrobe (Chronic...        4.19
#
#       ratings_count                                                url
# 80          16896.0  https://www.goodreads.com/book/show/845403.Muf...
# 299         21307.0  https://www.goodreads.com/book/show/20912424-t...
# 300          1278.0  https://www.goodreads.com/book/show/54383.The_...
# 322           518.0  https://www.goodreads.com/book/show/16241184-u...
# 612        471990.0  https://www.goodreads.com/book/show/5043.The_P...
# 704          8063.0  https://www.goodreads.com/book/show/15177.Brid...
# 1075         1467.0  https://www.goodreads.com/book/show/2535732.To...
# 1129         2221.0  https://www.goodreads.com/book/show/7052617-al...
# 1520      1575387.0  https://www.goodreads.com/book/show/100915.The...
# _____
